# %%
import pandas as pd

# %%
df = pd.read_csv("../src/all_files.csv")

# %%
df
# Out:
#                                                file_path   file_size  \
# 0      E:\Backup VLOGS\Episode Backup\1F56A9E0-9DBA-4...  1096337540
# 1      E:\Backup VLOGS\Episode Backup\230b8ad1df809e0...   776775471
# 2      E:\Backup VLOGS\Episode Backup\copy_1172E9FD-E...  1538686698
# 3      E:\Backup VLOGS\Episode Backup\copy_26368007-6...  1016518518
# 4      E:\Backup VLOGS\Episode Backup\copy_27EE13EF-9...  1840122717
# ...                                                  ...         ...
# 11649  E:\Backup VLOGS\SA trip\Uyuni\X3\VID_20241126_...   104857600
# 11650  E:\Backup VLOGS\SA trip\Uyuni\X3\VID_20241126_...   548907032
# 11651  E:\Backup VLOGS\SA trip\Uyuni\X3\VID_20241126_...   545259520
# 11652  E:\Backup VLOGS\SA trip\Uyuni\X3\VID_20241126_...   254338327
# 11653  E:\Backup VLOGS\SA trip\Uyuni\X3\VID_20241126_...   251658240
#
#                                     md5  created_time  \
# 0      24136d2e4f2ad85fe1f849074f26e8bf  1.743862e+09
# ...

# %%
duplicates_df = df[df.duplicated('md5', keep=False)].sort_values('md5')

# %%
duplicates_df
# Out:
#                                                file_path   file_size  \
# 3344   E:\Backup VLOGS\Kyrgyzstan\Issykul day 7\actio...    11029894
# 3343   E:\Backup VLOGS\Kyrgyzstan\Issykul day 7\actio...    11029894
# 1792   E:\Backup VLOGS\Kyrgyzstan\day 6\action 5pro\D...    35261162
# 1791   E:\Backup VLOGS\Kyrgyzstan\day 6\action 5pro\D...    35261162
# 10468  E:\Backup VLOGS\SA trip\Sheregesh\X3\VID_20250...  7404491928
# ...                                                  ...         ...
# 3165   E:\Backup VLOGS\Kyrgyzstan\Issykul day 7\actio...   188024842
# 2005   E:\Backup VLOGS\Kyrgyzstan\day 8\action 5 pro\...    61269035
# 2009   E:\Backup VLOGS\Kyrgyzstan\day 8\action 5 pro\...    61269035
# 8736   E:\Backup VLOGS\SA trip\Panama\DJI_20241222161...     4259884
# 8739   E:\Backup VLOGS\SA trip\Panama\DJI_20241222161...     4259884
#
#                                     md5  created_time  \
# 3344   01128c5dab78b5e70c9e2ac9b6bed543  1.746873e+09
# ...
